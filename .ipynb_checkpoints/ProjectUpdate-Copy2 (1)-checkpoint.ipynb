# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('C:/Users/rsant/OneDrive/Desktop/Machine Learning Project/Combined_News_DJIA.csv', encoding = "ISO-8859-1")

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Data Cleaning

# %% [markdown]
# Steps:
# 1. Check for missing data
# 1. Rename the Column Header
# 2. Remove punctuation Marks and Html tags
# 3. Lower the case
# 4. Join the 25 news headlines columns to create a single BOW for each date row
# 5. Check if the data is imbalanced

# %%
#drop empty columns
print(df.isna().sum())
df= df.dropna(axis=0, how='any')

df=df.reset_index(drop=True)
print(len(df))
data=df.iloc[:,2:27]
# Out:
# Date     0
# Label    0
# Top1     0
# Top2     0
# Top3     0
# Top4     0
# Top5     0
# Top6     0
# Top7     0
# Top8     0
# Top9     0
# Top10    0
# Top11    0
# Top12    0
# Top13    0
# Top14    0
# Top15    0
# Top16    0
# Top17    0
# Top18    0
# Top19    0
# Top20    0
# Top21    0
# Top22    0
# Top23    1
# Top24    3
# Top25    3
# dtype: int64
# 1986

# %%
# Renaming column names for ease of access
list1= range(25)
data.columns = list1

# %%
#removing punctuations
data.replace("[^a-zA-Z]"," ",regex=True, inplace=True)

#remove character tags
punctuation = "b"
for i in range(0,25):
    for j in range(len(data)):
        data.iloc[j,i]=' '.join([x.strip(punctuation) for x in data.iloc[j,i].split()])

# %%
#joining all the headlines
headlines = []
for row in range(0,len(data.index)):
    headlines.append(' '.join(str(x) for x in data.iloc[row,0:25]))
df['merge_headline'] = headlines
df['merge_headline'].head()
# Out:
# 0     Georgia downs two Russian warplanes as countr...
# 1     Why wont America and Nato help us If they won...
# 2     Remember that adorable year old who sang at t...
# 3     U S refuses Israel weapons to attack Iran rep...
# 4     All the experts admit that we should legalise...
# Name: merge_headline, dtype: object

# %%
#check the 
df.Label.value_counts()
# Out:
# 1    1062
# 0     924
# Name: Label, dtype: int64

# %%
df.Label.value_counts().plot(kind="bar")
plt.title("Class-Imbalance Check")
plt.xlabel("Classes")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
from gensim.utils import simple_preprocess
# Tokenize the text column to get the new column 'tokenized_text'
df['merge_headline'] = [simple_preprocess(line, deacc=True) for line in df['merge_headline'] ] 
df['merge_headline']= df['merge_headline'].apply(lambda x: " ".join(x) )
df['merge_headline']
# Out:
# 0       georgia downs two russian warplanes as countri...
# 1       why wont america and nato help us if they wont...
# 2       remember that adorable year old who sang at th...
# 3       refuses israel weapons to attack iran report w...
# 4       all the experts admit that we should legalise ...
#                               ...
# 1981    barclays and rbs shares suspended from trading...
# 1982    scientists to australia if you want to save th...
# 1983    explosion at airport in istanbul yemeni former...
# 1984    jamaica proposes marijuana dispensers for tour...
# 1985    year old woman in mexico city finally received...
# Name: merge_headline, Length: 1986, dtype: object

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
def remove_stopwords(text):
    tokens = nltk.word_tokenize(text)
    filtered_tokens = [token for token in tokens if token.lower() not in stop_words]
    return ' '.join(filtered_tokens)
df['merge_headline']= df['merge_headline'].apply(remove_stopwords)
df['merge_headline']
# Out:
# 0       georgia downs two russian warplanes countries ...
# 1       wont america nato help us wont help us help ir...
# 2       remember adorable year old sang opening ceremo...
# 3       refuses israel weapons attack iran report pres...
# 4       experts admit legalise drugs war south osetia ...
#                               ...
# 1981    barclays rbs shares suspended trading tanking ...
# 1982    scientists australia want save great barrier r...
# 1983    explosion airport istanbul yemeni former presi...
# 1984    jamaica proposes marijuana dispensers tourists...
# 1985    year old woman mexico city finally received ir...
# Name: merge_headline, Length: 1986, dtype: object

# %%
import pandas as pd
import nltk
from nltk.corpus import words

# Load the English words corpus from NLTK
english_words = set(words.words())

def remove_non_english_words(text):
    tokens = nltk.word_tokenize(text)
    filtered_tokens = [token for token in tokens if token.lower() in english_words]
    return ' '.join(filtered_tokens)
df['merge_headline']= df['merge_headline'].apply(remove_non_english_words)
df['merge_headline']
# Out:
# 0       two move rink war breaking russia today roll s...
# 1       wont help us wont help us help bush foot confl...
# 2       remember adorable year old sang opening fake r...
# 3       attack report president ordered attack capital...
# 4       admit war south made soldier wrestler ara away...
#                               ...
# 1981    suspended trading pope church ask forgiveness ...
# 1982    want save great barrier reef stop supporting c...
# 1983    explosion airport former president terrorism o...
# 1984    marijuana following would give people license ...
# 1985    year old woman city finally received certifica...
# Name: merge_headline, Length: 1986, dtype: object

# %%
from nltk.stem import PorterStemmer

# Define a stemmer
stemmer = PorterStemmer()

# Define a function to apply stemming to a text
def apply_stemming(text):
    tokens = nltk.word_tokenize(text)
    stemmed_tokens = [stemmer.stem(token) for token in tokens]
    return ' '.join(stemmed_tokens)

# Apply the function to the text column
df['merge_headline'] = df['merge_headline'].apply(apply_stemming)

# %%
from sklearn.feature_extraction.text import CountVectorizer
basictrain = CountVectorizer().fit(df['merge_headline'])
basictrain.get_feature_names_out()
# Out:
# array(['aa', 'aam', 'aback', ..., 'zoologist', 'zoom', 'zwanzig'],
#       dtype=object)

# %%
len(basictrain.get_feature_names())
# Out:
# 10511

# %%
all_words = ' '.join([text for text in df['merge_headline']]) 
import matplotlib.pyplot as plt 
from wordcloud import WordCloud
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(all_words) 
plt.figure(figsize=(10, 7)) 
plt.imshow(wordcloud, interpolation="bilinear") 
plt.axis('off')
plt.show()

# %%
up_words =' '.join([text for text in df['merge_headline'][df['Label'] == 0]]) 

wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(up_words)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
down_words =' '.join([text for text in df['merge_headline'][df['Label'] == 1]]) 

wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(down_words)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df['merge_headline'],df['Label'],test_size=0.3,random_state=42)

# %%
basictrain_1 = CountVectorizer().fit(X_train)
basictrain_1.get_feature_names_out()[::2000]
# Out:
# array(['aa', 'delug', 'inconsol', 'plotter', 'subsequ'], dtype=object)

# %%
len(basictrain_1.get_feature_names_out())
# Out:
# 9489

# %%
X_train_vector = basictrain_1.transform(X_train)
X_train_vector
# Out:
# <1390x9489 sparse matrix of type '<class 'numpy.int64'>'
# 	with 211090 stored elements in Compressed Sparse Row format>

# %%
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(solver='lbfgs', max_iter=3000)
model.fit(X_train_vector, y_train)
predictions_train = model.predict(X_train_vector)
print('Accuracy Score when threshold is defualt(0.5) train:', accuracy_score(y_train, predictions_train))
predictions_test = model.predict(basictrain_1.transform(X_test))
print('Accuracy Score when threshold is defualt(0.5) test:', accuracy_score(y_test, predictions_test))
# Out:
# Accuracy Score when threshold is defualt(0.5) train: 1.0
# Accuracy Score when threshold is defualt(0.5) test: 0.4714765100671141

# %%
bow_vector = CountVectorizer(max_df=0.95, min_df=0.05)
bow_X_train= bow_vector.fit(X_train)
len(bow_vector.get_feature_names_out())
# Out:
# 743

# %%
X_bow_train_vector = bow_vector.transform(X_train)
X_bow_train_vector.shape
# Out:
# (1390, 743)

# %%
bow_vector.vocabulary_
# Out:
# {'polic': 462,
#  'kill': 320,
#  'iceland': 288,
#  'first': 217,
#  'time': 671,
#  'ever': 191,
#  'pope': 468,
#  'night': 418,
#  'help': 272,
#  'sourc': 606,
#  'entir': 187,
#  'villag': 702,
#  'riot': 543,
#  'middl': 384,
#  'taken': 653,
#  'station': 626,
#  'start': 624,
#  'ga': 240,
#  'local': 356,
#  'opposit': 438,
#  'public': 498,
#  'servic': 578,
#  'must': 403,
#  'year': 738,
#  'old': 432,
#  'develop': 154,
#  'clear': 92,
#  'land': 326,
#  'hous': 283,
#  'project': 492,
#  'japan': 312,
#  'move': 399,
#  'made': 364,
#  'speech': 615,
#  'rich': 540,
#  'peopl': 450,
#  'test': 663,
#  'live': 355,
#  'north': 421,
#  'second': 563,
#  'power': 473,
#  'man': 367,
#  'kim': 321,
#  'two': 690,
#  'execut': 195,
#  'last': 328,
#  'month': 396,
#  'recent': 519,
#  'accord': 4,
#  'anti': 40,
#  'gay': 242,
#  'group': 261,
#  'video': 701,
#  'former': 228,
#  'one': 434,
#  'govern': 257,
#  'terrorist': 662,
#  'watch': 714,
#  'list': 353,
#  'case': 73,
#  'goe': 253,
#  'trial': 686,
#  'massiv': 376,
#  'terror': 661,
#  'fli': 220,
#  'crisi': 126,
#  'get': 246,
#  'seriou': 577,
#  'hong': 281,
#  'human': 285,
#  'court': 120,
#  'gulf': 265,
#  'spill': 618,
#  'bay': 59,
#  'claim': 89,
#  'tortur': 677,
#  'guardian': 263,
#  'spi': 617,
#  'world': 731,
#  'news': 415,
#  'zimbabw': 741,
#  'worth': 734,
#  'use': 698,
#  'trade': 681,
#  'currenc': 131,
#  'us': 697,
#  'privaci': 483,
#  'secur': 566,
#  'reveal': 538,
#  'set': 579,
#  'great': 258,
#  'protect': 495,
#  'region': 525,
#  'drive': 162,
#  'drug': 165,
#  'avoid': 56,
#  'put': 501,
#  'risk': 545,
#  'investig': 307,
#  'allegedli': 27,
#  'squar': 620,
#  'un': 691,
#  'senior': 574,
#  'offici': 430,
#  'launch': 331,
#  'surveil': 647,
#  'intellig': 303,
#  'follow': 222,
#  'secret': 564,
#  'phone': 454,
#  'offic': 429,
#  'lawyer': 333,
#  'east': 170,
#  'oil': 431,
#  'industri': 297,
#  'vote': 707,
#  'age': 15,
#  'new': 414,
#  'elect': 179,
#  'corrupt': 115,
#  'flight': 221,
#  'missil': 392,
#  'air': 22,
#  'defenc': 148,
#  'system': 651,
#  'want': 709,
#  'giant': 247,
#  'refus': 523,
#  'red': 521,
#  'six': 597,
#  'state': 625,
#  'face': 199,
#  'way': 716,
#  'take': 652,
#  'place': 456,
#  'intern': 305,
#  'union': 693,
#  'presid': 475,
#  'style': 640,
#  'revolut': 539,
#  'ring': 542,
#  'global': 251,
#  'actual': 12,
#  'quit': 502,
#  'sex': 583,
#  'abus': 1,
#  'went': 720,
#  'report': 530,
#  'minist': 389,
#  'earth': 168,
#  'anoth': 39,
#  'climat': 93,
#  'chang': 80,
#  'let': 344,
#  'number': 425,
#  'show': 590,
#  'rais': 506,
#  'health': 271,
#  'join': 314,
#  'give': 249,
#  'lack': 325,
#  'south': 607,
#  'success': 641,
#  'fire': 215,
#  'hit': 277,
#  'major': 365,
#  'attack': 52,
#  'town': 680,
#  'west': 721,
#  'fight': 209,
#  'eastern': 171,
#  'sinc': 594,
#  'come': 99,
#  'effect': 177,
#  'consid': 109,
#  'suicid': 643,
#  'three': 670,
#  'without': 728,
#  'crash': 123,
#  'mission': 393,
#  'found': 229,
#  'grow': 262,
#  'full': 237,
#  'fuel': 236,
#  'fund': 238,
#  'call': 65,
#  'cup': 130,
#  'resign': 534,
#  'king': 322,
#  'shut': 591,
#  'park': 443,
#  'tri': 685,
#  'prepar': 474,
#  'war': 710,
#  'russia': 552,
#  'pacif': 442,
#  'past': 447,
#  'caus': 77,
#  'sell': 572,
#  'could': 117,
#  'economi': 175,
#  'eu': 189,
#  'top': 676,
#  'feder': 207,
#  'lead': 334,
#  'across': 7,
#  'work': 730,
#  'china': 85,
#  'educ': 176,
#  'never': 413,
#  'respons': 535,
#  'mani': 368,
#  'western': 722,
#  'constitut': 110,
#  'inquiri': 300,
#  'life': 347,
#  'men': 383,
#  'young': 740,
#  'sexual': 584,
#  'plane': 458,
#  'alreadi': 32,
#  'eat': 172,
#  'femal': 208,
#  'team': 656,
#  'leader': 335,
#  'least': 337,
#  'everi': 192,
#  'commun': 101,
#  'technolog': 657,
#  'far': 204,
#  'mother': 398,
#  'strike': 636,
#  'german': 245,
#  'threaten': 669,
#  'end': 183,
#  'aid': 21,
#  'die': 155,
#  'swiss': 650,
#  'militari': 386,
#  'oper': 436,
#  'nation': 406,
#  'anonym': 38,
#  'expos': 197,
#  'auster': 54,
#  'level': 346,
#  'prison': 482,
#  'act': 8,
#  'plan': 457,
#  'lock': 357,
#  'insid': 301,
#  'privat': 484,
#  'run': 551,
#  'outsid': 441,
#  'urn': 696,
#  'teen': 658,
#  'jail': 311,
#  'may': 377,
#  'much': 401,
#  'real': 515,
#  'campaign': 67,
#  'support': 645,
#  'special': 614,
#  'destroy': 153,
#  'aircraft': 23,
#  'bank': 58,
#  'illeg': 291,
#  'law': 332,
#  'condemn': 105,
#  'settlement': 580,
#  'legal': 341,
#  'yet': 739,
#  'continu': 112,
#  'reach': 512,
#  'involv': 308,
#  'despit': 152,
#  'evid': 193,
#  'fraud': 232,
#  'spark': 611,
#  'sent': 575,
#  'ground': 260,
#  'death': 142,
#  'massacr': 375,
#  'strip': 637,
#  'street': 635,
#  'polit': 464,
#  'parti': 446,
#  'accus': 6,
#  'next': 417,
#  'threat': 668,
#  'ancient': 37,
#  'current': 132,
#  'collaps': 97,
#  'even': 190,
#  'father': 205,
#  'regim': 524,
#  'shoot': 588,
#  'protest': 496,
#  'dead': 139,
#  'injur': 299,
#  'due': 166,
#  'rise': 544,
#  'nearli': 410,
#  'percent': 452,
#  'lost': 362,
#  'centuri': 79,
#  'final': 212,
#  'releas': 526,
#  'shot': 589,
#  'million': 387,
#  'forc': 225,
#  'like': 349,
#  'point': 461,
#  'pirat': 455,
#  'know': 323,
#  'said': 554,
#  'remain': 528,
#  'readi': 513,
#  'nuclear': 424,
#  'tell': 659,
#  'interview': 306,
#  'control': 113,
#  'within': 727,
#  'gener': 243,
#  'spread': 619,
#  'al': 25,
#  'author': 55,
#  'given': 250,
#  'pro': 486,
#  'democraci': 151,
#  'econom': 174,
#  'five': 219,
#  'low': 363,
#  'ahead': 20,
#  'wound': 736,
#  'remov': 529,
#  'religi': 527,
#  'plot': 460,
#  'water': 715,
#  'suppli': 644,
#  'island': 309,
#  'day': 138,
#  'drink': 161,
#  'plant': 459,
#  'countri': 119,
#  'price': 480,
#  'canada': 68,
#  'still': 630,
#  'foreign': 226,
#  'natur': 407,
#  'week': 718,
#  'energi': 184,
#  'solar': 601,
#  'huge': 284,
#  'poll': 465,
#  'among': 36,
#  'damag': 134,
#  'suspect': 648,
#  'wors': 732,
#  'thought': 667,
#  'worst': 733,
#  'environment': 188,
#  'disast': 158,
#  'turkey': 687,
#  'record': 520,
#  'find': 214,
#  'sea': 561,
#  'ice': 287,
#  'chief': 83,
#  'twitter': 689,
#  'inform': 298,
#  'data': 136,
#  'leav': 338,
#  'front': 235,
#  'citi': 87,
#  'controversi': 114,
#  'today': 672,
#  'clean': 91,
#  'return': 537,
#  'food': 223,
#  'small': 598,
#  'cash': 74,
#  'wear': 717,
#  'decis': 146,
#  'mine': 388,
#  'hard': 269,
#  'deadli': 140,
#  'shell': 585,
#  'school': 560,
#  'miss': 391,
#  'search': 562,
#  'southern': 608,
#  'danger': 135,
#  'media': 379,
#  'say': 557,
#  'emerg': 182,
#  'spend': 616,
#  'white': 724,
#  'viru': 705,
#  'confirm': 106,
#  'organ': 440,
#  'think': 665,
#  'person': 453,
#  'crime': 124,
#  'justic': 317,
#  'financi': 213,
#  'civil': 88,
#  'legisl': 342,
#  'key': 319,
#  'arrest': 48,
#  'armi': 46,
#  'activ': 10,
#  'ara': 43,
#  'diplomat': 156,
#  'oppos': 437,
#  'prime': 481,
#  'embassi': 181,
#  'carri': 72,
#  'free': 233,
#  'access': 3,
#  'whether': 723,
#  'central': 78,
#  'told': 673,
#  'unit': 694,
#  'led': 339,
#  'would': 735,
#  'see': 567,
#  'home': 279,
#  'independ': 296,
#  'rule': 550,
#  'part': 445,
#  'problem': 488,
#  'decid': 145,
#  'speak': 612,
#  'train': 682,
#  'ralli': 507,
#  'increas': 295,
#  'movement': 400,
#  'well': 719,
#  'violenc': 703,
#  'rape': 509,
#  'om': 433,
#  'site': 596,
#  'mayor': 378,
#  'offens': 427,
#  'univers': 695,
#  'also': 33,
#  'total': 678,
#  'ex': 194,
#  'agenc': 16,
#  'link': 352,
#  'right': 541,
#  'poor': 467,
#  'meet': 381,
#  'rebel': 517,
#  'seiz': 570,
#  'fear': 206,
#  'cathol': 75,
#  'guilti': 264,
#  'child': 84,
#  'assault': 50,
#  'ambassador': 34,
#  'leak': 336,
#  'light': 348,
#  'newspap': 416,
#  'anyon': 41,
#  'open': 435,
#  'scandal': 559,
#  'rocket': 547,
#  'ase': 49,
#  'near': 409,
#  'order': 439,
#  'probe': 487,
#  'away': 57,
#  'long': 358,
#  'highest': 274,
#  'command': 100,
#  'drone': 163,
#  'stop': 633,
#  'marriag': 373,
#  'tax': 655,
#  'hack': 266,
#  'money': 395,
#  'coal': 95,
#  'high': 273,
#  'win': 726,
#  'prize': 485,
#  'pay': 448,
#  'around': 47,
#  'fish': 218,
#  'post': 471,
#  'dutch': 167,
#  'propos': 494,
#  'cover': 121,
#  'nine': 419,
#  'brazil': 63,
#  'speci': 613,
#  'ocean': 426,
#  'warn': 712,
#  'treatment': 684,
#  'cost': 116,
#  'less': 343,
#  'almost': 30,
#  'make': 366,
#  'per': 451,
#  'woman': 729,
#  'go': 252,
#  'safe': 553,
#  'church': 86,
#  'murder': 402,
#  'son': 604,
#  'caught': 76,
#  'raid': 505,
#  'stolen': 632,
#  'agre': 18,
#  'journalist': 315,
#  'self': 571,
#  'account': 5,
#  'camp': 66,
#  'histor': 275,
#  'id': 289,
#  'keep': 318,
#  'market': 371,
#  'cross': 128,
#  'line': 351,
#  'rang': 508,
#  'northern': 422,
#  'network': 412,
#  'futur': 239,
#  'toni': 674,
#  'capit': 70,
#  'appar': 42,
#  'rare': 510,
#  'seen': 569,
#  'enough': 185,
#  'freedom': 234,
#  'th': 664,
#  'deal': 141,
#  'debt': 144,
#  'prevent': 479,
#  'warm': 711,
#  'four': 231,
#  'area': 44,
#  'airport': 24,
#  'film': 211,
#  'save': 556,
#  'coast': 96,
#  'ship': 586,
#  'aliv': 26,
#  'student': 638,
#  'sign': 593,
#  'cut': 133,
#  'accept': 2,
#  'offer': 428,
#  'ill': 290,
#  'sentenc': 576,
#  'fail': 200,
#  'half': 267,
#  'famili': 203,
#  'studi': 639,
#  'extrem': 198,
#  'shock': 587,
#  'issu': 310,
#  'singl': 595,
#  'longer': 359,
#  'ad': 13,
#  'rate': 511,
#  'soldier': 603,
#  'allow': 29,
#  'council': 118,
#  'punish': 499,
#  'marri': 372,
#  'founder': 230,
#  'earthquak': 169,
#  'gang': 241,
#  'potenti': 472,
#  'interest': 304,
#  'popul': 469,
#  'along': 31,
#  'social': 599,
#  'turn': 688,
#  'wife': 725,
#  'histori': 276,
#  'left': 340,
#  'medic': 380,
#  'research': 533,
#  'compani': 102,
#  'product': 490,
#  'conflict': 107,
#  'construct': 111,
#  'asylum': 51,
#  'sever': 582,
#  'green': 259,
#  'larg': 327,
#  'mass': 374,
#  'attempt': 53,
#  'explos': 196,
#  'staff': 622,
#  'cultur': 129,
#  'receiv': 518,
#  'amid': 35,
#  'possibl': 470,
#  'defens': 149,
#  'cancer': 69,
#  'seven': 581,
#  'parliament': 444,
#  'societi': 600,
#  'agreement': 19,
#  'row': 549,
#  'gold': 254,
#  'took': 675,
#  'scale': 558,
#  'charg': 81,
#  'peac': 449,
#  'side': 592,
#  'hold': 278,
#  'radiat': 503,
#  'step': 629,
#  'radic': 504,
#  'head': 270,
#  'lose': 361,
#  'discov': 159,
#  'ut': 699,
#  'concern': 104,
#  'st': 621,
#  'immigr': 292,
#  'pressur': 478,
#  'modern': 394,
#  'reak': 514,
#  'enter': 186,
#  'victim': 700,
#  'produc': 489,
#  'close': 94,
#  'soviet': 609,
#  'member': 382,
#  'judg': 316,
#  'visit': 706,
#  'reportedli': 531,
#  'jo': 313,
#  'eight': 178,
#  'target': 654,
#  'wrong': 737,
#  'firm': 216,
#  'role': 548,
#  'propaganda': 493,
#  'car': 71,
#  'mysteri': 404,
#  'critic': 127,
#  'send': 573,
#  'suprem': 646,
#  'suffer': 642,
#  'later': 329,
#  'hunt': 286,
#  'third': 666,
#  'stand': 623,
#  'chemic': 82,
#  'crimin': 125,
#  'fighter': 210,
#  'hospit': 282,
#  'realli': 516,
#  'stori': 634,
#  'sale': 555,
#  'violent': 704,
#  'demand': 150,
#  'instead': 302,
#  'marijuana': 370,
#  'ago': 17,
#  'girl': 248,
#  'daughter': 137,
#  'known': 324,
#  'need': 411,
#  'wast': 713,
#  'push': 500,
#  'zone': 742,
#  'might': 385,
#  'fake': 201,
#  'direct': 157,
#  'polici': 463,
#  'provid': 497,
#  'class': 90,
#  'suspend': 649,
#  'press': 477,
#  'footag': 224,
#  'result': 536,
#  'travel': 683,
#  'good': 255,
#  'conserv': 108,
#  'ministri': 390,
#  'toward': 679,
#  'bush': 64,
#  'non': 420,
#  'includ': 294,
#  'fall': 202,
#  'presidenti': 476,
#  'complet': 103,
#  'unemploy': 692,
#  'debat': 143,
#  'look': 360,
#  'republ': 532,
#  'drop': 164,
#  'littl': 354,
#  'electr': 180,
#  'stock': 631,
#  'soon': 605,
#  'limit': 350,
#  'arm': 45,
#  'eaten': 173,
#  'name': 405,
#  'bill': 60,
#  'latest': 330,
#  'program': 491,
#  'march': 369,
#  'road': 546,
#  'billion': 61,
#  'got': 256,
#  'reduc': 522,
#  'dollar': 160,
#  'stay': 628,
#  'admit': 14,
#  'blair': 62,
#  'space': 610,
#  'alli': 28,
#  'sold': 602,
#  'declar': 147,
#  'action': 9,
#  'mosqu': 397,
#  'abort': 0,
#  'statu': 627,
#  'navi': 408,
#  'pollut': 466,
#  'combat': 98,
#  'seek': 568,
#  'activist': 11,
#  'territori': 660,
#  'import': 293,
#  'genocid': 244,
#  'letter': 345,
#  'hand': 268,
#  'form': 227,
#  'crackdown': 122,
#  'wall': 708,
#  'secretari': 565,
#  'noth': 423,
#  'homosexu': 280}

# %%
word_list = bow_vector.get_feature_names() 
count_list = X_bow_train_vector.toarray().sum(axis=0)

# %%
import matplotlib.pyplot as plt

# Create a dictionary of the word counts
word_counts = dict(zip(word_list, count_list))

# Sort the words by their counts in descending order
sorted_word_counts = dict(sorted(word_counts.items(), key=lambda item: item[1], reverse=True))

# Create a bar chart of the top 20 words
top_words = list(sorted_word_counts.keys())[:20]
word_counts = [sorted_word_counts[word] for word in top_words]

plt.bar(top_words, word_counts)
plt.xticks(rotation=90)
plt.xlabel('Words')
plt.ylabel('Count')
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a dictionary of the word counts
word_counts = dict(zip(word_list, count_list))

# Sort the words by their counts in descending order
sorted_word_counts = dict(sorted(word_counts.items(), key=lambda item: item[1], reverse=True))

# Create a bar chart of the top 20 words
top_words = list(sorted_word_counts.keys())[-20:]
word_counts = [sorted_word_counts[word] for word in top_words]

plt.bar(top_words, word_counts)
plt.xticks(rotation=90)
plt.xlabel('Words')
plt.ylabel('Count')
plt.show()

# %%
model.fit(X_bow_train_vector, y_train)
predictions_train = model.predict(X_bow_train_vector)
print('Accuracy Score when threshold is defualt(0.5) train:', accuracy_score(y_train, predictions_train))
predictions_test = model.predict(bow_vector.transform(X_test))
print('Accuracy Score when threshold is defualt(0.5) test:', accuracy_score(y_test, predictions_test))
# Out:
# Accuracy Score when threshold is defualt(0.5) train: 0.9201438848920863
# Accuracy Score when threshold is defualt(0.5) test: 0.4697986577181208

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
cf_matrix = confusion_matrix(y_test,predictions_test)
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
feature_names = np.array(bow_vector.get_feature_names())
sorted_coef_index = model.coef_[0].argsort()
print('Smallest Coefs:\n{}\n'.format(feature_names[sorted_coef_index[:10]]))
print('Largest Coefs: \n{}'.format(feature_names[sorted_coef_index[:-11:-1]]))
# Out:
# Smallest Coefs:
# ['fighter' 'account' 'whether' 'light' 'went' 'outsid' 'presidenti'
#  'emerg' 'stock' 'away']
#
# Largest Coefs:
# ['coast' 'propaganda' 'green' 'resign' 'seiz' 'self' 'control' 'southern'
#  'ministri' 'unemploy']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vector = TfidfVectorizer( max_df=0.95, min_df=0.05)
tfidf_X_train = tfidf_vector.fit(X_train)
tfidf_X_train_vector =tfidf_vector.transform(X_train)
len(tfidf_vector.get_feature_names_out())
# Out:
# 743

# %%
model.fit(tfidf_X_train_vector, y_train)
predictions_test = model.predict(tfidf_vector.transform(X_test))
predictions_train = model.predict(tfidf_vector.transform(X_train))

print('Accuracy Score when threshold is defualt(0.5) train:', accuracy_score(y_train, predictions_train))
print('Accuracy Score when threshold is defualt(0.5) test:', accuracy_score(y_test, predictions_test))
# Out:
# Accuracy Score when threshold is defualt(0.5) train: 0.7784172661870503
# Accuracy Score when threshold is defualt(0.5) test: 0.4899328859060403

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vector_1 = TfidfVectorizer(max_df=0.95, min_df=0.05, ngram_range=(1,2) )
tfidf_X_train_1 = tfidf_vector_1.fit(X_train)
tfidf_X_train_vector_1 =tfidf_vector_1.transform(X_train)
len(tfidf_vector_1.get_feature_names_out())
# Out:
# 757

# %%
model.fit(tfidf_X_train_vector_1, y_train)
predictions_test = model.predict(tfidf_vector_1.transform(X_test))
predictions_train = model.predict(tfidf_vector_1.transform(X_train))
print('Accuracy Score when threshold is defualt(0.5) train:', accuracy_score(y_train, predictions_train))
print('Accuracy Score when threshold is defualt(0.5) test:', accuracy_score(y_test, predictions_test))
# Out:
# Accuracy Score when threshold is defualt(0.5) train: 0.7798561151079136
# Accuracy Score when threshold is defualt(0.5) test: 0.49328859060402686

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
cf_matrix = confusion_matrix(y_test,predictions_test)
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Cross-Validation

# %%
from sklearn.model_selection import cross_val_score,KFold
kf=KFold(n_splits=5)
score=cross_val_score(model,tfidf_X_train_vector_1, y_train,cv=kf)
print("Cross Validation Scores are {}".format(score))
print("Average Cross Validation score :{}".format(score.mean()))
# Out:
# Cross Validation Scores are [0.56834532 0.56115108 0.51798561 0.56115108 0.51438849]
# Average Cross Validation score :0.5446043165467626

# %% [markdown]
# Dimension Reduction Using Lasso

# %%
accuracies_1 = []
accuracies_2 = []
Cs = []
C_range =np.logspace(np.log10(0.1), np.log10(100), num=50)
# loop through each value of C and fit a logistic regression model
for C in C_range:
    # create a logistic regression model with L1 regularization and the given value of C
    logistic_lasso = LogisticRegression(penalty='l1', solver='saga', C=C, max_iter=5000)
    logistic_lasso.fit(tfidf_X_train_vector_1, y_train)
    
    # evaluate the accuracy of the model on the validation set
    acc_train = logistic_lasso.score(tfidf_X_train_vector_1, y_train)
    acc_test = logistic_lasso.score(tfidf_vector_1.transform(X_test), y_test)
    # append the accuracy and C values to the lists
    accuracies_1.append(acc_train)
    accuracies_2.append(acc_test)
    Cs.append(C)

# %%
# plot the accuracies versus the C values
plt.plot(Cs, accuracies_1)
plt.xlabel('C')
plt.ylabel('Accuracy')
plt.xscale('log')
plt.show()

# %%
logistic_lasso = LogisticRegression(penalty='l1', solver='saga', C=3, max_iter=5000)
logistic_lasso.fit(tfidf_X_train_vector_1, y_train)
var_names = tfidf_vector_1.get_feature_names()
count_list = tfidf_X_train_vector_1.toarray().sum(axis=0)
variables_of_interest = []
variables_coeff = []
count = []
for beta in range(len(logistic_lasso.coef_[0])):
    if logistic_lasso.coef_[0][beta] !=0:
        variables_of_interest.append(var_names[beta])
        variables_coeff.append(logistic_lasso.coef_[0][beta])
        count.append(count_list[beta])
variable = pd.DataFrame(
    {'variables_of_interest': variables_of_interest,
     'variables_coeff': variables_coeff,
     'count_list': count
     
    })

count_list = tfidf_X_train_vector_1.toarray().sum(axis=0)

variable.sort_values('variables_coeff')
# Out:
#     variables_of_interest  variables_coeff  count_list
# 0                 account        -6.400094    9.747163
# 100               fighter        -5.698919    9.012666
# 262                   run        -5.554017   23.772168
# 354               whether        -4.863121    9.239241
# 351                  went        -4.710466    8.272232
# ..                    ...              ...         ...
# 296              southern         3.542674   11.520309
# 304                 state         3.833790   43.855079
# 273                  seiz         3.896270    9.019767
# 330                 today         4.599252   20.001678
# 48                  coast         4.794286   14.123178
#
# [366 rows x 3 columns]

# %%
vocabulary = tfidf_vector_1.vocabulary_

# Create a list of indices to keep based on the variables_of_interest
keep_indices = [vocabulary[word] for word in variables_of_interest if word in vocabulary]

# Create a new transformed document-term matrix with only the selected features
X_train_selected = tfidf_X_train_vector_1[:, keep_indices]
X_test_vector =  tfidf_vector_1.transform(X_test)[:, keep_indices]
X_train_selected.shape
X_test_vector.shape
# Out:
# (596, 366)

# %%
logistic_lasso.fit(X_train_selected, y_train)
predictions_test = logistic_lasso.predict(X_test_vector)
predictions_train = logistic_lasso.predict(X_train_selected)
print('Accuracy Score when threshold is defualt(0.5) train:', accuracy_score(y_train, predictions_train))
print('Accuracy Score when threshold is defualt(0.5) test:', accuracy_score(y_test, predictions_test))
# Out:
# Accuracy Score when threshold is defualt(0.5) train: 0.8201438848920863
# Accuracy Score when threshold is defualt(0.5) test: 0.47818791946308725

# %%
print('important features count', sum(logistic_lasso.coef_[0]!=0))
# Out:
# important features count 366

# %%
from sklearn.naive_bayes import MultinomialNB
MNB = MultinomialNB()
MNB.fit(X_train_selected, y_train)
predictions_test = MNB.predict(X_test_vector)
predictions_train = MNB.predict(X_train_selected)
print('Accuracy Score when threshold is defualt(0.5) train:', accuracy_score(y_train, predictions_train))
print('Accuracy Score when threshold is defualt(0.5) test:', accuracy_score(y_test, predictions_test))
# Out:
# Accuracy Score when threshold is defualt(0.5) train: 0.6410071942446043
# Accuracy Score when threshold is defualt(0.5) test: 0.511744966442953

# %%
prediction =MNB.predict_proba(X_test_vector)
pd.DataFrame(prediction, columns=MNB.classes_)
# Out:
#             0         1
# 0    0.448244  0.551756
# 1    0.458347  0.541653
# 2    0.433475  0.566525
# 3    0.460246  0.539754
# 4    0.447407  0.552593
# ..        ...       ...
# 591  0.456410  0.543590
# 592  0.440979  0.559021
# 593  0.489767  0.510233
# 594  0.383693  0.616307
# 595  0.483085  0.516915
#
# [596 rows x 2 columns]

# %%
from sklearn.datasets import make_classification
alphas = {'alpha': np.logspace(-3, 3, 7)}
grid = GridSearchCV(MNB, alphas, cv=5)
grid.fit(X_train_selected, y_train)
# plot alpha vs accuracy
plt.semilogx(alphas['alpha'], grid.cv_results_['mean_test_score'])
plt.title('Alpha vs Accuracy')
plt.xlabel('Alpha')
plt.ylabel('Accuracy')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3380\989790565.py in <module>
#       1 from sklearn.datasets import make_classification
#       2 alphas = {'alpha': np.logspace(-3, 3, 7)}
# ----> 3 grid = GridSearchCV(MNB, alphas, cv=5)
#       4 grid.fit(X_train_selected, y_train)
#       5 # plot alpha vs accuracy
#
# NameError: name 'GridSearchCV' is not defined

# %%
from sklearn.naive_bayes import MultinomialNB
MNB = MultinomialNB(alpha =0.01)
MNB.fit(X_train_selected, y_train)
predictions_test = MNB.predict(X_test_vector)
predictions_train = MNB.predict(X_train_selected)
print('Accuracy Score when threshold is defualt(0.5) train:', accuracy_score(y_train, predictions_train))
print('Accuracy Score when threshold is defualt(0.5) test:', accuracy_score(y_test, predictions_test))
# Out:
# Accuracy Score when threshold is defualt(0.5) train: 0.6633093525179856
# Accuracy Score when threshold is defualt(0.5) test: 0.5134228187919463

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
cf_matrix = confusion_matrix(y_test,predictions_test)
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
param_grid = {'learning_rate':[0.001],
              'max_depth': [1,3,5,7],
              'n_estimators':[100,200,300,400,500, 600]}

# Create a gradient boosting classifier object
gb = GradientBoostingClassifier(random_state=42)

# Perform grid search with cross-validation
grid_search = GridSearchCV(gb, param_grid=param_grid, cv=5)
grid_search.fit(tfidf_X_train_vector_1, y_train)

# Print the best hyperparameters and the corresponding accuracy score
print("Best hyperparameters: ", grid_search.best_params_)
print("Best accuracy score: ", grid_search.best_score_)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15508\3343845465.py in <module>
#      10 # Perform grid search with cross-validation
#      11 grid_search = GridSearchCV(gb, param_grid=param_grid, cv=5)
# ---> 12 grid_search.fit(tfidf_X_train_vector_1, y_train)
#      13
#      14 # Print the best hyperparameters and the corresponding accuracy score
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     889                 return results
#     890
# --> 891             self._run_search(evaluate_candidates)
#     892
#     893             # multimetric is determined here because in the case of a callable
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1390     def _run_search(self, evaluate_candidates):
#    1391         """Search all candidates in param_grid"""
# -> 1392         evaluate_candidates(ParameterGrid(self.param_grid))
#    1393
#    1394
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     836                     )
#     837
# --> 838                 out = parallel(
#     839                     delayed(_fit_and_score)(
#     840                         clone(base_estimator),
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1044                 self._iterating = self._original_iterator is not None
#    1045
# -> 1046             while self.dispatch_one_batch(iterator):
#    1047                 pass
#    1048
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     859                 return False
#     860             else:
# --> 861                 self._dispatch(tasks)
#     862                 return True
#     863
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     777         with self._lock:
#     778             job_idx = len(self._jobs)
# --> 779             job = self._backend.apply_async(batch, callback=cb)
#     780             # A job can complete so quickly than its callback is
#     781             # called before we get here, causing self._jobs to
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\anaconda3\lib\site-packages\sklearn\utils\fixes.py in __call__(self, *args, **kwargs)
#     214     def __call__(self, *args, **kwargs):
#     215         with config_context(**self.config):
# --> 216             return self.function(*args, **kwargs)
#     217
#     218
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     678             estimator.fit(X_train, **fit_params)
#     679         else:
# --> 680             estimator.fit(X_train, y_train, **fit_params)
#     681
#     682     except Exception:
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py in fit(self, X, y, sample_weight, monitor)
#     584
#     585         # fit the boosting stages
# --> 586         n_stages = self._fit_stages(
#     587             X,
#     588             y,
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py in _fit_stages(self, X, y, raw_predictions, sample_weight, random_state, X_val, y_val, sample_weight_val, begin_at_stage, monitor)
#     661
#     662             # fit next stage of trees
# --> 663             raw_predictions = self._fit_stage(
#     664                 i,
#     665                 X,
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py in _fit_stage(self, i, X, y, raw_predictions, sample_weight, sample_mask, random_state, X_csc, X_csr)
#     244
#     245             X = X_csr if X_csr is not None else X
# --> 246             tree.fit(X, residual, sample_weight=sample_weight, check_input=False)
#     247
#     248             # update tree leaves
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1313         """
#    1314
# -> 1315         super().fit(
#    1316             X,
#    1317             y,
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     418             )
#     419
# --> 420         builder.build(self.tree_, X, y, sample_weight)
#     421
#     422         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:

# %%
# Evaluate the final model on the test set
final_model = grid_search.best_estimator_
test_accuracy = final_model.score(tfidf_vector_1.transform(X_test), y_test)
print("Test set accuracy: ", test_accuracy)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt


k_values = range(1, 10)

accuracy_scores = []

for k in k_values:
    
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(tfidf_X_train_vector_1, y_train)
    y_pred = knn.predict(tfidf_X_train_vector_1)
    accuracy = accuracy_score(y_train, y_pred)
    accuracy_scores.append(accuracy)

# Plot the accuracy scores as a function of k
plt.plot(k_values, accuracy_scores)
plt.xlabel('Number of neighbors (k)')
plt.ylabel('Accuracy')
plt.title('KNN Accuracy as a function of k')
plt.show()

# %%
knn = KNeighborsClassifier(n_neighbors=4)
knn.fit(tfidf_X_train_vector_1, y_train)
y_pred = knn.predict(tfidf_vector_1.transform(X_test))
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.4966442953020134

# %%
from sklearn.tree import DecisionTreeClassifier, export_graphviz,  plot_tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn import tree

# %%
#### Fitting classification trees
criteria = "gini" 
max_depth = 6 
min_sample_leaf = 4
clf_gini = DecisionTreeClassifier(criterion=criteria, random_state=100,
                                max_depth=max_depth, min_samples_leaf=min_sample_leaf)
clf_gini.fit(tfidf_X_train_vector, y_train)
print(clf_gini.score(tfidf_X_train_vector, y_train))

#### Fitting classification trees (ERROR)
# one attractive feature of a tree is visulization. 
plt.figure(figsize=(5,10))  # customize according to the size of your tree
plot_tree(clf_gini, feature_names= tfidf_X_train_vector)
plt.show()
# Out:
# 0.5920863309352518

# %%
y_pred_train = clf_gini.predict(tfidf_X_train_vector)
cm = pd.DataFrame(confusion_matrix(y_train, y_pred_train).T, index=['No', 'Yes'], columns=['No', 'Yes'])
print("Train Accuracy is ", accuracy_score(y_train,y_pred_train)*100)
y_pred = clf_gini.predict(tfidf_vector.transform(X_test))
cm = pd.DataFrame(confusion_matrix(y_test, y_pred).T, index=['No', 'Yes'], columns=['No', 'Yes'])
print("Test Accuracy is ", accuracy_score(y_test,y_pred)*100)
# Out:
#       No  Yes
# No    84   11
# Yes  556  739
# Train Accuracy is  59.20863309352518
#       No  Yes
# No    23   19
# Yes  261  293
# Test Accuracy is  53.02013422818792

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
cf_matrix = confusion_matrix(y_test,y_pred)
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Bagging

# %%
#### Bagging and random forests 
all_features = tfidf_X_train_vector.shape[1]
all_features
# Out:
# 743

# %%
regr_bagging = RandomForestClassifier(max_features=743, random_state=1)

# %%
regr_bagging.fit(tfidf_X_train_vector, y_train)
y_pred_train = regr_bagging.predict(tfidf_X_train_vector)
#### Bagging and random forests 
y_pred = regr_bagging.predict(tfidf_vector.transform(X_test))

# %%
print("Train Accuracy is ", accuracy_score(y_train,y_pred_train)*100)
# Out:
# Train Accuracy is  100.0

# %%
print("Test Accuracy is ", accuracy_score(y_test,y_pred)*100)
# Out:
# Test Accuracy is  48.99328859060403

# %%
regr_rf = RandomForestClassifier(max_features=27,n_estimators=100, random_state=1)
regr_rf.fit(tfidf_X_train_vector, y_train)
y_pred = regr_rf.predict(tfidf_vector.transform(X_test))
y_pred_train = regr_rf.predict(tfidf_X_train_vector)
print("Train Accuracy is ", accuracy_score(y_train,y_pred_train)*100)
print("Test Accuracy is ", accuracy_score(y_test,y_pred)*100)
# Out:
# Train Accuracy is  100.0
# Test Accuracy is  50.33557046979866

# %%
regr_rf = RandomForestClassifier(max_features=i,n_estimators=100, random_state=1)
regr_rf.fit(tfidf_X_train_vector, y_train)
y_pred = regr_rf.predict(tfidf_vector.transform(X_test))
y_pred_train = regr_rf.predict(tfidf_X_train_vector)
print("")
print("Train Accuracy is ", accuracy_score(y_train,y_pred_train)*100)
print("Test Accuracy is ", accuracy_score(y_test,y_pred)*100)
# Out:
# Train Accuracy is  100.0
# Test Accuracy is  50.33557046979866

# %%
feature =[]
trees = []
